# %%
import pdftotext

# %%
path = 'CV_WojciechMaciejewski.pdf'

# Load your PDF
with open(path, "rb") as f:
    pdf = pdftotext.PDF(f)

# If it's password-protected
with open(path, "rb") as f:
    pdf = pdftotext.PDF(f, "secret")

# How many pages?
print(len(pdf))

# Iterate over all the pages
for page in pdf:
    print(page)

# Read some individual pages
print(pdf[0])
print(pdf[1])

# Read all the text into one string
full_text = "\n\n".join(pdf)
print(full_text)
# Out:
# 2
# WOJCIECH                                                                                502 452 672
#                                                                wojciech.maciejewski271@gmail.com
# MACIEJEWSKI                                https:/www.linkedin.com/in/wojciech-maciejewski271
#                                                                        https://github.com/Laszer271
# I am a deep learning specialist with a passion for generative models, natural language processing
# and computer vision. I have extensive knowledge and experience in applying state-of-the-art
# techniques and frameworks to various domains and challenges. I aspire to work in R&D in deep
# learning and contribute to the scientific community with my own publications.
# ABOUT ME
#     •   Leading a Generative Models study group for 4+ years, researching generative models such
#         as variational autoencoder (VAE), generative adversarial network (GAN) and diffusion models
#         (DM) in image generation.
#     •   Participating in 10+ hackathons and competitions and won 3 awards: 1st place in Bitehack
#         2022 in sentiment analysis category and 3rd place in AI Games 2020 in flight’s delay
#         prediction, 3rd place AI Games 2022 in flight’s trajectory prediction.
#     •   Being involved in activities of the Artificial Intelligence Society Golem, including giving
#         lectures and leading a project team.
#     •   Attending conferences, reading papers, and participating in scientific debates to stay
#         updated with the rapidly changing industry.
# EDUCATION
# Warsaw University of Technology, The Faculty of Electronics and Information
# Technology, Computer Science
# 2017 – 2022
# EXPERIENCE
# Junior Data Scientist | Schneider Electric
# JUNE 2022 – PRESENT
#     •   Designing and testing machine learning solutions for time-series forecasting, using sklearn,
#         statsforecast, skforecast and pandas, that is replacing manual processes that costed
#         company over €7 million annually.
#     •   Helping with designing and creating OOP backend of the forecasting application using
#         Python, SQL, Spark and Databricks.
#     •   Preparing visualizations of the experiments for presenting results to shareholders and clients
#         mainly using pandas and plotly.
# Data Scientist | 2Take.it
# SEPTEMBER 2020 – NOVEMBER 2020
#     •   Data processing in pandas that was used by the rest of the dev team.
#     •   Creating of descriptive statistics used in the dashboard shared with clients.
#     •   Generating and maintaining html reports for our clients.
# Intern Data Scientist | Nielsen
# AUGUST 2019 – JANUARY 2020
#     •   Designing backend application for web scraping leveraging OOP and multithreading.
#     •   Writing customized web scraping programs for 100+ websites.
#     •   Training employees in web scraping so that the project could be continued after I left.
#     •   Taking part in an international project for a client in e-commerce.
#     •   Big Data analysis and processing of the data provided by the client.
#
# SKILLS
# Python
# NumPy, Pandas, PyTorch, Tensorflow+Keras, scikit-learn, Matplotlib, Plotly, SciPy, Pillow, OpenCV,
# BeautifulSoup, Selenium, re, wandb, mlflow, Spark
# Deep Learning
# MLPs, CNNs, GANs, VAEs, diffusion models, Autoencoders, Transformers, RNNs,
# Machine Learning
# sklearn’s models (e.g. tree-based models), statistical models for time-series forecasting (e.g. ARIMA),
# forecasting approaches (e.g. recursive), optimization algorithms (e.g. evolutionary algorithms)
# Other Technologies
# SQL, regex, C, C++, Java, HTML, JavaScript, Git, MS Office, Linux, Windows, Bash
# Soft
# English C1, Polish native, analytical thinking, creativity, team leading, fast learning
#
# WOJCIECH                                                                                502 452 672
#                                                                wojciech.maciejewski271@gmail.com
# MACIEJEWSKI                                https:/www.linkedin.com/in/wojciech-maciejewski271
#                                                                        https://github.com/Laszer271
# I am a deep learning specialist with a passion for generative models, natural language processing
# and computer vision. I have extensive knowledge and experience in applying state-of-the-art
# techniques and frameworks to various domains and challenges. I aspire to work in R&D in deep
# learning and contribute to the scientific community with my own publications.
# ABOUT ME
#     •   Leading a Generative Models study group for 4+ years, researching generative models such
#         as variational autoencoder (VAE), generative adversarial network (GAN) and diffusion models
#         (DM) in image generation.
#     •   Participating in 10+ hackathons and competitions and won 3 awards: 1st place in Bitehack
#         2022 in sentiment analysis category and 3rd place in AI Games 2020 in flight’s delay
#         prediction, 3rd place AI Games 2022 in flight’s trajectory prediction.
#     •   Being involved in activities of the Artificial Intelligence Society Golem, including giving
#         lectures and leading a project team.
#     •   Attending conferences, reading papers, and participating in scientific debates to stay
#         updated with the rapidly changing industry.
# EDUCATION
# Warsaw University of Technology, The Faculty of Electronics and Information
# Technology, Computer Science
# 2017 – 2022
# EXPERIENCE
# Junior Data Scientist | Schneider Electric
# JUNE 2022 – PRESENT
#     •   Designing and testing machine learning solutions for time-series forecasting, using sklearn,
#         statsforecast, skforecast and pandas, that is replacing manual processes that costed
#         company over €7 million annually.
#     •   Helping with designing and creating OOP backend of the forecasting application using
#         Python, SQL, Spark and Databricks.
#     •   Preparing visualizations of the experiments for presenting results to shareholders and clients
#         mainly using pandas and plotly.
# Data Scientist | 2Take.it
# SEPTEMBER 2020 – NOVEMBER 2020
#     •   Data processing in pandas that was used by the rest of the dev team.
#     •   Creating of descriptive statistics used in the dashboard shared with clients.
#     •   Generating and maintaining html reports for our clients.
# Intern Data Scientist | Nielsen
# AUGUST 2019 – JANUARY 2020
#     •   Designing backend application for web scraping leveraging OOP and multithreading.
#     •   Writing customized web scraping programs for 100+ websites.
#     •   Training employees in web scraping so that the project could be continued after I left.
#     •   Taking part in an international project for a client in e-commerce.
#     •   Big Data analysis and processing of the data provided by the client.
#
# SKILLS
# Python
# NumPy, Pandas, PyTorch, Tensorflow+Keras, scikit-learn, Matplotlib, Plotly, SciPy, Pillow, OpenCV,
# BeautifulSoup, Selenium, re, wandb, mlflow, Spark
# Deep Learning
# MLPs, CNNs, GANs, VAEs, diffusion models, Autoencoders, Transformers, RNNs,
# Machine Learning
# sklearn’s models (e.g. tree-based models), statistical models for time-series forecasting (e.g. ARIMA),
# forecasting approaches (e.g. recursive), optimization algorithms (e.g. evolutionary algorithms)
# Other Technologies
# SQL, regex, C, C++, Java, HTML, JavaScript, Git, MS Office, Linux, Windows, Bash
# Soft
# English C1, Polish native, analytical thinking, creativity, team leading, fast learning
#
# WOJCIECH                                                                                502 452 672
#                                                                wojciech.maciejewski271@gmail.com
# MACIEJEWSKI                                https:/www.linkedin.com/in/wojciech-maciejewski271
#                                                                        https://github.com/Laszer271
# I am a deep learning specialist with a passion for generative models, natural language processing
# and computer vision. I have extensive knowledge and experience in applying state-of-the-art
# techniques and frameworks to various domains and challenges. I aspire to work in R&D in deep
# learning and contribute to the scientific community with my own publications.
# ABOUT ME
#     •   Leading a Generative Models study group for 4+ years, researching generative models such
#         as variational autoencoder (VAE), generative adversarial network (GAN) and diffusion models
#         (DM) in image generation.
#     •   Participating in 10+ hackathons and competitions and won 3 awards: 1st place in Bitehack
#         2022 in sentiment analysis category and 3rd place in AI Games 2020 in flight’s delay
#         prediction, 3rd place AI Games 2022 in flight’s trajectory prediction.
#     •   Being involved in activities of the Artificial Intelligence Society Golem, including giving
#         lectures and leading a project team.
#     •   Attending conferences, reading papers, and participating in scientific debates to stay
#         updated with the rapidly changing industry.
# EDUCATION
# Warsaw University of Technology, The Faculty of Electronics and Information
# Technology, Computer Science
# 2017 – 2022
# EXPERIENCE
# Junior Data Scientist | Schneider Electric
# JUNE 2022 – PRESENT
#     •   Designing and testing machine learning solutions for time-series forecasting, using sklearn,
#         statsforecast, skforecast and pandas, that is replacing manual processes that costed
#         company over €7 million annually.
#     •   Helping with designing and creating OOP backend of the forecasting application using
#         Python, SQL, Spark and Databricks.
#     •   Preparing visualizations of the experiments for presenting results to shareholders and clients
#         mainly using pandas and plotly.
# Data Scientist | 2Take.it
# SEPTEMBER 2020 – NOVEMBER 2020
#     •   Data processing in pandas that was used by the rest of the dev team.
#     •   Creating of descriptive statistics used in the dashboard shared with clients.
#     •   Generating and maintaining html reports for our clients.
# Intern Data Scientist | Nielsen
# AUGUST 2019 – JANUARY 2020
#     •   Designing backend application for web scraping leveraging OOP and multithreading.
#     •   Writing customized web scraping programs for 100+ websites.
#     •   Training employees in web scraping so that the project could be continued after I left.
#     •   Taking part in an international project for a client in e-commerce.
#     •   Big Data analysis and processing of the data provided by the client.
#
#
# SKILLS
# Python
# NumPy, Pandas, PyTorch, Tensorflow+Keras, scikit-learn, Matplotlib, Plotly, SciPy, Pillow, OpenCV,
# BeautifulSoup, Selenium, re, wandb, mlflow, Spark
# Deep Learning
# MLPs, CNNs, GANs, VAEs, diffusion models, Autoencoders, Transformers, RNNs,
# Machine Learning
# sklearn’s models (e.g. tree-based models), statistical models for time-series forecasting (e.g. ARIMA),
# forecasting approaches (e.g. recursive), optimization algorithms (e.g. evolutionary algorithms)
# Other Technologies
# SQL, regex, C, C++, Java, HTML, JavaScript, Git, MS Office, Linux, Windows, Bash
# Soft
# English C1, Polish native, analytical thinking, creativity, team leading, fast learning

# %%
len(full_text.split())
# Out:
# 457
